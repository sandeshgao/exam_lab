# %% [markdown]
# <a href="https://colab.research.google.com/github/sandeshgao/exam_lab/blob/main/deny_all_ingress.yaml" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
---
apiVersion: networking.k8s.io/v1
kind: NetworkPolicy
metadata:
  name: default-deny-ingress
spec:
  podSelector: {}
  policyTypes:
  - Ingress
